# %% [markdown]
#  - [Description](#desc)
#  - [Name](#name)
#  - [Photo](#photo)
#  - [Last Trip](#lasttrip)
#  - [Armenia](#inarm)
#  - [Last Vlog](#vlog)

# %% [markdown]
# Description <a class="anchor" id="desc"></a>

# %% [markdown]
# This file contains contents from a travel blogger who went to see Armenia

# %% [markdown]
# Name <a class="anchor" id="name"></a>

# %%
name=input()
# Out:
# TravelGirl

# %% [markdown]
# Photo <a class="anchor" id="photo"></a>

# %%
print(name)
# Out:
# TravelGirl

# %% [markdown]
# ![Image.PNG](attachment:Image.PNG)

# %% [markdown]
# Last trip <a class="anchor" id="lasttrip"></a>

# %%
Question = input("When did you do have your last holidays?")
# Out:
# When did you do have your last holidays?Summer

# %%
if Question == ("Summer"):
        print ("Armenia, Georgia")
elif Question == ("Winter"):
        print ("Egypt, Cyprus, Portugal")
else:
        print("I had to prep for exams")
# Out:
# Armenia, Georgia

# %% [markdown]
# Armenia trip <a class="anchor" id="inarm"></a>

# %% [markdown]
# ![Travel.PNG](attachment:Travel.PNG)

# %% [markdown]
# - What TravelGirl likes to do in Armenia
#      - Eat
#      - Eat
#      - Eat

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Things to do:</b> Visit cultral sites, eat lots of food, go to lakes in the coutryside
# </div>

# %% [markdown]
# Latest Vlog <a class="anchor" id="vlog"></a>

# %% [markdown]
# [TravelGirl visiting Armenia Vlog](https://www.youtube.com/watch?v=zfl7ITJ8kGk&ab_channel=EvazuBeck)
